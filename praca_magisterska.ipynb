# %%
import pandas as pd
import numpy as np
import torch

from datasets import load_dataset
import seaborn as sns
import plotly.express as ex

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load Sythetic data

# %%
df_synth = pd.read_csv("./data/reviews_data_final.tsv", sep="\t")

# %%
df_synth = df_synth.dropna(axis=0).reset_index()

# %%
df_synth
# Out:
#       index    id                                             prompt
# 0         0     0  Create three film reviews about the same film....  \
# 1         1     1  Create three film reviews about the same film....
# 2         2     2  Create three film reviews about the same film....
# 3         3     3  Create three film reviews about the same film....
# 4         4     4  Create three film reviews about the same film....
# ...     ...   ...                                                ...
# 4907   5294  5294  Create three film reviews about the same film:...
# 4908   5295  5295  Create three film reviews about the same film....
# 4909   5296  5296  Create three film reviews about the same film....
# 4910   5297  5297  Create three film reviews about the same film....
# 4911   5298  5298  Create three film reviews about the same film....
#
#                                             chatgpt_out
# 0     ['The movie had a lot of potential, but the CG...  \
# ...

# %%
review_list_synth = []
review_list_synth.extend(df_synth['review1'].values.tolist())
review_list_synth.extend(df_synth['review2'].values.tolist())
review_list_synth.extend(df_synth['review3'].values.tolist())

labels_synth = [0 for x in range(len(review_list_synth))]

# %%
df_synth_list = pd.DataFrame({"text" : review_list_synth, "label" : labels_synth})
df_synth_list.to_csv("./data/negative_reviews.csv", sep=";")

# %% [markdown]
# https://paperswithcode.com/dataset/imdb-movie-reviews

# %% [markdown]
# ## Load imdb data

# %%
dataset_train = load_dataset("imdb", split="train")
dataset_test = load_dataset("imdb", split="test")

df_train = pd.DataFrame(dataset_train)
df_test = pd.DataFrame(dataset_test)
# Out:
# Found cached dataset imdb (/home/erthax/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0)
# Found cached dataset imdb (/home/erthax/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0)

# %%
df_train
# Out:
#                                                     text  label
# 0      I rented I AM CURIOUS-YELLOW from my video sto...      0
# 1      "I Am Curious: Yellow" is a risible and preten...      0
# 2      If only to avoid making this type of film in t...      0
# 3      This film was probably inspired by Godard's Ma...      0
# 4      Oh, brother...after hearing about this ridicul...      0
# ...                                                  ...    ...
# 24995  A hit at the time but now better categorised a...      1
# 24996  I love this movie like no other. Another time ...      1
# 24997  This film and it's sequel Barry Mckenzie holds...      1
# 24998  'The Adventures Of Barry McKenzie' started lif...      1
# 24999  The story centers around Barry McKenzie who mu...      1
#
# [25000 rows x 2 columns]
